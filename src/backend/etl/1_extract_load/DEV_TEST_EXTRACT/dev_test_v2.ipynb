# %%
import os
import time
import pandas as pd
import investpy as inv
import yfinance as yf
from google.cloud import bigquery
from google.api_core.exceptions import NotFound

# %%
import yfinance as yf

B3 = yf.Ticker("B3SA3.SA")

# get all stock info
B3.info
# Out:
# {'address1': 'PraCa Antonio Prado, 48',
#  'address2': 'Rua XV de Novembro, 275 Centro',
#  'city': 'São Paulo',
#  'state': 'SP',
#  'zip': '18970-020',
#  'country': 'Brazil',
#  'website': 'https://www.b3.com.br',
#  'industry': 'Financial Data & Stock Exchanges',
#  'industryKey': 'financial-data-stock-exchanges',
#  'industryDisp': 'Financial Data & Stock Exchanges',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'B3 S.A. - Brasil, Bolsa, Balcão, a financial market infrastructure company, provides trading services in an exchange and OTC environment. It operates through Listed; OTC; Infrastructure for Financing; and Technology, Data and Service segments. The company offers listed equities and securities for anhydrous fuel ethanol, Arabica coffee 4/5 and 6/7, corn, crystal sugar, gold, hydrous ethanol, live cattle, and soybean commodities; ETF and sovereign debt instruments; and exchange rates, interest rates, and equities, as well as collateral management products. It also provides OTC derivatives; decarbonization credit, derivatives contracted abroad, and B3 electricity platform; OTC market products, as well as agribusiness, banking funding, bonds, mortgage, securities registration, treasury bond, and other financial securities; registration services for structured transaction certificates; and netting agreement and ESG, as well as clearing and settlement services. In addition, the company offers trading participant; central depository; broad, corporate governance, segment, sustainability, sector, and other indices, as well as indices in partnership with S&P DowJones; and Tesouro Direto, an alternative investment product. Further, it provides market data services that include services related to quotes, distributors, historical data, and reports; UP2DATA, DATAWISE, and UP2DATA ON DEMAND data services; and financing market information services. Additionally, the company offers various platforms, such as PUMA trading system, trading interface, InsurConnect, Middle and backoffice, Risk Management \x96 LINE, Real Estate Market Collateral, and Risk Management \x96 Financing; connectivity; and hosting and colocation services. The company was formerly known as BM&FBOVESPA S.A. - Bolsa de Valores, Mercadorias e Futuros and changed its name to B3 S.A. - Brasil, Bolsa, Balcão in June 2017. The company was incorporated in 2007 and is headquartered in São Paulo, Brazil.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Gilson  Finkelsztain',
#    'age': 51,
#    'title': 'CEO & President of Statutory Board',
#    'yearBorn': 1972,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Andre Veiga Milanez',
#    'title': 'Chief Financial, Corp and Investor Relations Off& Mem of stat Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jose Ribeiro de Andrade',
#    'age': 55,
#    'title': 'Chief Product & Client Officer and Member of Statutory Board',
#    'yearBorn': 1968,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rodrigo Antonio Nardoni Goncales',
#    'age': 50,
#    'title': 'Chief Technology Officer, Cybersecurity, Information Off and Mem of Statry Board',
#    'yearBorn': 1973,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ana Carla Abrao Costa',
#    'age': 54,
#    'title': 'Chief Business Development Officer & Member of Statutory Board',
#    'yearBorn': 1969,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Marcos Vanderlei Belini Ferreira',
#    'age': 54,
#    'title': 'Chief Financing Infrastructure Unit Officer & Member of Statutory Board',
#    'yearBorn': 1969,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Viviane El Banate Basso',
#    'age': 46,
#    'title': 'Chief Operating Officer of Issuers, Depositary & OTC and Member of Statutory Board',
#    'yearBorn': 1977,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mario Rodrigo Leitzke Palhares',
#    'age': 49,
#    'title': 'Chief Operating Officer of Electronic Trading & CCP and Member of Statutory Board',
#    'yearBorn': 1974,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ana Christina Buchaim Gagliardi',
#    'age': 45,
#    'title': 'Chief of People, Brand, Comm., Sust. & Social Inv. and Member of Statutory Board',
#    'yearBorn': 1978,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Eduardo Lopes Farias',
#    'age': 47,
#    'title': 'Executive Director of Governance, Integrated Mgmt & Cyber ??Security and Member of Statutory Board',
#    'yearBorn': 1976,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 1,
#  'compensationRisk': 7,
#  'shareHolderRightsRisk': 6,
#  'overallRisk': 1,
#  'governanceEpochDate': 1717200000,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 10.88,
#  'regularMarketPreviousClose': 10.88,
#  'dividendRate': 0.33,
#  'dividendYield': 0.0304,
#  'exDividendDate': 1711497600,
#  'payoutRatio': 0.62689996,
#  'fiveYearAvgDividendYield': 2.91,
#  'beta': 0.54,
#  'trailingPE': 15.285714,
#  'forwardPE': 11.382978,
#  'averageVolume': 46775246,
#  'averageVolume10days': 44592630,
#  'averageDailyVolume10Day': 44592630,
#  'bid': 10.65,
#  'ask': 10.73,
#  'marketCap': 59090751488,
#  'fiftyTwoWeekHigh': 15.52,
#  'priceToSalesTrailing12Months': 6.60826,
#  'fiftyDayAverage': 11.4408,
#  'twoHundredDayAverage': 12.5609,
#  'trailingAnnualDividendRate': 0.022,
#  'trailingAnnualDividendYield': 0.0020220587,
#  'currency': 'BRL',
#  'enterpriseValue': 57465696256,
#  'profitMargins': 0.44645,
#  'floatShares': 5571443512,
#  'sharesOutstanding': 5522500096,
#  'heldPercentInstitutions': 0.69649005,
#  'impliedSharesOutstanding': 5586540032,
#  'bookValue': 3.567,
#  'priceToBook': 2.9997196,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1711843200,
#  'earningsQuarterlyGrowth': -0.128,
#  'netIncomeToCommon': 3992161024,
#  'trailingEps': 0.7,
#  'forwardEps': 0.94,
#  'pegRatio': 18.5,
#  'lastSplitFactor': '3:1',
#  'lastSplitDate': 1621209600,
#  'enterpriseToRevenue': 6.427,
#  'enterpriseToEbitda': 11.184,
#  '52WeekChange': -0.26002765,
#  'SandP52WeekChange': 0.23485482,
#  'lastDividendValue': 0.052453,
#  'lastDividendDate': 1711497600,
#  'exchange': 'SAO',
#  'quoteType': 'EQUITY',
#  'symbol': 'B3SA3.SA',
#  'underlyingSymbol': 'B3SA3.SA',
#  'shortName': 'B3          ON      NM',
#  'longName': 'B3 S.A. - Brasil, Bolsa, Balcão',
#  'firstTradeDateEpochUtc': 1193400000,
#  'timeZoneFullName': 'America/Sao_Paulo',
#  'timeZoneShortName': 'BRT',
#  'uuid': '7fc68f31-45e1-31c9-a638-51c1279bb8de',
#  'messageBoardId': 'finmb_21953226',
#  'gmtOffSetMilliseconds': -10800000,
#  'currentPrice': 10.7,
#  'targetHighPrice': 17.0,
#  'targetLowPrice': 11.4,
#  'targetMeanPrice': 14.81,
#  'targetMedianPrice': 15.0,
#  'recommendationMean': 2.5,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 11,
#  'totalCash': 16950749184,
#  'totalCashPerShare': 3.042,
#  'ebitda': 5138313216,
#  'totalDebt': 14789424128,
#  'quickRatio': 1.903,
#  'currentRatio': 1.934,
#  'totalRevenue': 8941953024,
#  'debtToEquity': 74.365,
#  'revenuePerShare': 1.581,
#  'returnOnAssets': 0.06915,
#  'returnOnEquity': 0.19742,
#  'freeCashflow': 3533335040,
#  'operatingCashflow': 3932878080,
#  'earningsGrowth': -0.1,
#  'revenueGrowth': 0.005,
#  'grossMargins': 0.96772003,
#  'ebitdaMargins': 0.57463,
#  'operatingMargins': 0.58377,
#  'financialCurrency': 'BRL',
#  'trailingPegRatio': None}
